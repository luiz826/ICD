# %% [markdown]
# # Introdução à Ciência de Dados - UFPB
# Professor: Yuri Malheiros
#
# ## Python - Random - Exercício

# %% [markdown]
# Implemente a função `generate_password` que deve gerar uma senha aleatória.
#
# A função tem tres parâmetros:
#
# - `n_chars` especifica o tamanho da senha gerada
# - `use_numbers` especifica se números podem ser usados na senha. Por padrão, esse parâmetro tem valor True
# - `use_special_chars` especifica se caracteres especiais, por exemplo !#%&@?, pode ser usados na senha. Por padrão, esse parâmetro tem valor True
#
# Note que se `use_numbers` e `use_special_chars` tiverem valor False, a senha terá apenas letras maiúsculas ou minúsculas.

# %%
import random

def generate_password(n_chars, use_numbers=True, use_special_chars=True):
    caracteres = []
    
    abc = [chr(i) for i in range(97, 123)]
    ABC = list(map(lambda x: x.upper(), abc))
    
    caracteres.extend(abc)
    caracteres.extend(ABC)
    
    if use_numbers:
        numbers = [chr(i) for i in range(48, 58)]
        caracteres.extend(numbers)
        
    if use_special_chars:
        special = [chr(i) for i in range(33, 48)]
        special.extend([chr(i) for i in range(58, 65)])
        special.extend([chr(i) for i in range(91, 97)])
        special.extend([chr(i) for i in range(123, 127)])
        caracteres.extend(special)
    
    password = []
    for i in range(n_chars):
        password.append(random.choice(caracteres))

    return "".join(password)

# %%
print(generate_password(10))
print(generate_password(10, use_numbers=False))
print(generate_password(10, use_numbers=False, use_special_chars=False))
# Out:
# _^($Ie7W=L
# -q/|j|>Kud
# rKgPTTnXdy

# %% [markdown]
# OBS: Estou reenviando a solução porque eu tinha feito utilizando o sample. Mesmo sabendo que agora posso utilizar o método string para deixar o programa mais completo, não irei utiliza-lo, pois na minha solução inicial eu não o utilizei e eu não queria deixar o código muito diferente da primeira versão que eu fiz.
